# %%
# importing all necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('athlete_events.csv') # read file

# data.head() display first 5 entry
# data.describe about model
# data.info give info about data
print(data.head(), data.describe(), data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192306 entries, 0 to 192305
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      192306 non-null  int64
#  1   Name    192306 non-null  object
#  2   Sex     192306 non-null  object
#  3   Age     185576 non-null  float64
#  4   Height  149418 non-null  float64
#  5   Weight  147362 non-null  float64
#  6   Team    192306 non-null  object
#  7   NOC     192306 non-null  object
#  8   Games   192305 non-null  object
#  9   Year    192305 non-null  float64
#  10  Season  192305 non-null  object
#  11  City    192305 non-null  object
#  12  Sport   192305 non-null  object
#  13  Event   192305 non-null  object
#  14  Medal   27839 non-null   object
# dtypes: float64(4), int64(1), object(10)
# memory usage: 22.0+ MB
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games    Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992.0  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012.0  Summer     London           Judo
# 2  DEN  1920 Summer  1920.0  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900.0  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988.0  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN                     ID            Age         Height         Weight  \
# count  192306.000000  185576.000000  149418.000000  147362.000000
# mean    48605.529281      25.558235     175.378288      70.733415
# std     27703.677287       6.410567      10.462333      14.275206
# min         1.000000      10.000000     127.000000      25.000000
# 25%     24788.250000      21.000000     168.000000      60.000000
# 50%     48681.500000      24.000000     175.000000      70.000000
# 75%     72385.000000      28.000000     183.000000      79.000000
# max     96559.000000      96.000000     223.000000     214.000000
#
#                 Year
# count  192305.000000
# mean     1978.279816
# std        29.876104
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000   None

# %%
# regions and country noc data csv file
regions = pd.read_csv('datasets_31029_40943_noc_regions.csv')
print(regions.head())

# merging to data and regions frame
merged = pd.merge(data, regions, on='NOC', how='left')
print(merged.head())
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games    Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992.0  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012.0  Summer     London           Judo
# 2  DEN  1920 Summer  1920.0  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900.0  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988.0  Winter    Calgary  Speed Skating
#
#                               Event Medal       region notes
# 0       Basketball Men's Basketball   NaN        China   NaN
# 1      Judo Men's Extra-Lightweight   NaN        China   NaN
# 2           Football Men's Football   NaN      Denmark   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold      Denmark   NaN
# 4  Speed Skating Women's 500 metres   NaN  Netherlands   NaN

# %%
# creating goldmedal dataframes
goldMedals = merged[(merged.Medal == 'Gold')]
print(goldMedals.head())
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games    Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900.0  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948.0  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948.0  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948.0  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992.0  Winter  Albertville  Alpine Skiing
#
#                                Event Medal   region notes
# 3        Tug-Of-War Men's Tug-Of-War  Gold  Denmark   NaN
# 42  Gymnastics Men's Team All-Around  Gold  Finland   NaN
# 44      Gymnastics Men's Horse Vault  Gold  Finland   NaN
# 48  Gymnastics Men's Pommelled Horse  Gold  Finland   NaN
# 60       Alpine Skiing Men's Super G  Gold   Norway   NaN

# %%
plt.figure(figsize=(20, 10))
plt.title('Distribution of Gold Medals')
sns.countplot(goldMedals['Age'])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
goldMedals = merged[(merged.Medal == 'Gold')]
print('The no of athletes is',
	goldMedals['ID'][goldMedals['Age'] > 50].count(), '\n')
print(goldMedals[goldMedals['Age'] > 50])
# Out:
# The no of athletes is 35
#
#            ID                                     Name Sex   Age  Height  \
# 5078     2894                   Derek Swithin Allhusen   M  54.0   180.0
# 7961     4404                       Johan August Anker   M  56.0     NaN
# 13394    7272               Nikolaus "Klaus" Balkenhol   M  52.0   178.0
# 13396    7272               Nikolaus "Klaus" Balkenhol   M  56.0   178.0
# 24897   13033            Gustaf Adolf Boltenstern, Jr.   M  52.0     NaN
# 30323   15656                  Charles Granville Bruce   M  57.0     NaN
# 38675   19898                            Peter Charles   M  52.0   175.0
# 41288   21296           Lauritz Christian Christiansen   M  52.0     NaN
# 42973   22163                    Blair Onslow Cochrane   M  54.0     NaN
# 51671   26560            Hermann Alexandre de Pourtals   M  53.0     NaN
# 63622   32591                    Everard Coenraad Endt   M  59.0     NaN
# 73191   37203                        Johan Mohr Friele   M  53.0     NaN
# 78291   39739                Friedrich Wilhelm Gerhard   M  52.0     NaN
# 104003  52626                     Isaac Lazarus Israls   M  63.0     NaN
# 105010  53154         William Kilgour "Willie" Jackson   M  52.0     NaN
# 105199  53238                          Charles Jacobus   M  64.0     NaN
# 107171  54161                  Harry Wyndham Jefferson   M  51.0     NaN
# 110771  56030                       Andr Ren Jousseaum   M  53.0     NaN
# 121152  61257                            Reiner Klimke   M  52.0   184.0
# 131798  66323                Paul Maximilien Landowski   M  52.0     NaN
# 132007  66437               Santiago Ral Lange Roberti   M  54.0   184.0
# 134557  67726                      Maurice Marie Lecoq   M  52.0     NaN
# 139669  70134                             Ernst Linder   M  56.0     NaN
# 159298  79961                   Joshua Kearney Millner   M  60.0     NaN
# 163126  81899                       Lon Ernest Moreaux   M  54.0     NaN
# 163130  81899                       Lon Ernest Moreaux   M  54.0     NaN
# 167439  84123     Georges Lambert Casimir Nagelmackers   M  54.0     NaN
# 168551  84709                            Harald Natvig   M  51.0     NaN
# 169081  84997              Josef Carl Peter Neckermann   M  52.0   183.0
# 169083  84997              Josef Carl Peter Neckermann   M  56.0   183.0
# 170250  85547                      Sybil Fenton Newall   F  53.0     NaN
# 170796  85838           William Newzam Prior Nicholson   M  56.0     NaN
# 171029  85949                     Anders Peter Nielsen   M  52.0     NaN
# 173097  87000           William Herbert "Bill" Northam   M  59.0   183.0
# 190952  95906  Lida Peyton "Eliza" Pollock (McMillen-)   F  63.0     NaN
#
#         Weight                Team  NOC        Games    Year  Season  \
# 5078      71.0       Great Britain  GBR  1968 Summer  1968.0  Summer
# 7961       NaN               Norna  NOR  1928 Summer  1928.0  Summer
# 13394     83.0             Germany  GER  1992 Summer  1992.0  Summer
# 13396     83.0             Germany  GER  1996 Summer  1996.0  Summer
# 24897      NaN              Sweden  SWE  1956 Summer  1956.0  Summer
# 30323      NaN       Great Britain  GBR  1924 Winter  1924.0  Winter
# 38675     78.0       Great Britain  GBR  2012 Summer  2012.0  Summer
# 41288      NaN             Atlanta  NOR  1920 Summer  1920.0  Summer
# 42973      NaN            Cobweb-1  GBR  1908 Summer  1908.0  Summer
# 51671      NaN              Lerina  SUI  1900 Summer  1900.0  Summer
# 63622      NaN            Llanoria  USA  1952 Summer  1952.0  Summer
# 73191      NaN            Heira II  NOR  1920 Summer  1920.0  Summer
# 78291      NaN             Germany  GER  1936 Summer  1936.0  Summer
# 104003     NaN         Netherlands  NED  1928 Summer  1928.0  Summer
# 105010     NaN       Great Britain  GBR  1924 Winter  1924.0  Winter
# 105199     NaN       United States  USA  1904 Summer  1904.0  Summer
# 107171     NaN           Bona Fide  GBR  1900 Summer  1900.0  Summer
# 110771     NaN              France  FRA  1948 Summer  1948.0  Summer
# 121152    66.0        West Germany  FRG  1988 Summer  1988.0  Summer
# 131798     NaN              France  FRA  1928 Summer  1928.0  Summer
# 132007    73.0           Argentina  ARG  2016 Summer  2016.0  Summer
# 134557     NaN              France  FRA  1906 Summer  1906.0  Summer
# 139669     NaN              Sweden  SWE  1924 Summer  1924.0  Summer
# 159298     NaN       Great Britain  GBR  1908 Summer  1908.0  Summer
# 163126     NaN              France  FRA  1906 Summer  1906.0  Summer
# 163130     NaN              France  FRA  1906 Summer  1906.0  Summer
# 167439     NaN           Belgium-1  BEL  1900 Summer  1900.0  Summer
# 168551     NaN              Norway  NOR  1924 Summer  1924.0  Summer
# 169081    65.0             Germany  GER  1964 Summer  1964.0  Summer
# 169083    65.0        West Germany  FRG  1968 Summer  1968.0  Summer
# 170250     NaN       Great Britain  GBR  1908 Summer  1908.0  Summer
# 170796     NaN       Great Britain  GBR  1928 Summer  1928.0  Summer
# 171029     NaN             Denmark  DEN  1920 Summer  1920.0  Summer
# 173097    81.0          Barrenjoey  AUS  1964 Summer  1964.0  Summer
# 190952     NaN  Cincinnati Archers  USA  1904 Summer  1904.0  Summer
#
#                   City             Sport  \
# 5078       Mexico City     Equestrianism
# 7961         Amsterdam           Sailing
# 13394        Barcelona     Equestrianism
# 13396          Atlanta     Equestrianism
# 24897        Stockholm     Equestrianism
# 30323         Chamonix          Alpinism
# 38675           London     Equestrianism
# 41288        Antwerpen           Sailing
# 42973           London           Sailing
# 51671            Paris           Sailing
# 63622         Helsinki           Sailing
# 73191        Antwerpen           Sailing
# 78291           Berlin     Equestrianism
# 104003       Amsterdam  Art Competitions
# 105010        Chamonix           Curling
# 105199       St. Louis             Roque
# 107171           Paris           Sailing
# 110771          London     Equestrianism
# 121152           Seoul     Equestrianism
# 131798       Amsterdam  Art Competitions
# 132007  Rio de Janeiro           Sailing
# 134557          Athina          Shooting
# 139669           Paris     Equestrianism
# 159298          London          Shooting
# 163126          Athina          Shooting
# 163130          Athina          Shooting
# 167439           Paris     Equestrianism
# 168551           Paris          Shooting
# 169081           Tokyo     Equestrianism
# 169083     Mexico City     Equestrianism
# 170250          London           Archery
# 170796       Amsterdam  Art Competitions
# 171029       Antwerpen          Shooting
# 173097           Tokyo           Sailing
# 190952       St. Louis           Archery
#
#                                                     Event Medal       region  \
# 5078            Equestrianism Mixed Three-Day Event, Team  Gold           UK
# 7961                               Sailing Mixed 6 metres  Gold       Norway
# 13394                  Equestrianism Mixed Dressage, Team  Gold      Germany
# 13396                  Equestrianism Mixed Dressage, Team  Gold      Germany
# 24897                  Equestrianism Mixed Dressage, Team  Gold       Sweden
# 30323                             Alpinism Mixed Alpinism  Gold           UK
# 38675                   Equestrianism Mixed Jumping, Team  Gold           UK
# 41288                             Sailing Mixed 12 metres  Gold       Norway
# 42973                              Sailing Mixed 8 metres  Gold           UK
# 51671                               Sailing Mixed 1-2 Ton  Gold  Switzerland
# 63622                              Sailing Mixed 6 metres  Gold          USA
# 73191                             Sailing Mixed 12 metres  Gold       Norway
# 78291                  Equestrianism Men's Dressage, Team  Gold      Germany
# 104003         Art Competitions Mixed Painting, Paintings  Gold  Netherlands
# 105010                              Curling Men's Curling  Gold           UK
# 105199                                Roque Men's Singles  Gold          USA
# 107171                             Sailing Mixed 3-10 Ton  Gold           UK
# 110771                 Equestrianism Men's Dressage, Team  Gold       France
# 121152                 Equestrianism Mixed Dressage, Team  Gold      Germany
# 131798        Art Competitions Mixed Sculpturing, Statues  Gold       France
# 132007                            Sailing Mixed Multihull  Gold    Argentina
# 134557              Shooting Men's Free Pistol, 25 metres  Gold       France
# 139669           Equestrianism Men's Dressage, Individual  Gold       Sweden
# 159298             Shooting Men's Free Rifle, 1,000 Yards  Gold           UK
# 163126    Shooting Men's Dueling Pistol Au Vise 20 metres  Gold       France
# 163130  Shooting Men's Military Rifle, 1873-1874 Gras ...  Gold       France
# 167439       Equestrianism Mixed Four-In-Hand Competition  Gold      Belgium
# 168551   Shooting Men's Running Target, Single Shot, Team  Gold       Norway
# 169081                 Equestrianism Mixed Dressage, Team  Gold      Germany
# 169083                 Equestrianism Mixed Dressage, Team  Gold      Germany
# 170250              Archery Women's Double National Round  Gold           UK
# 170796      Art Competitions Mixed Painting, Graphic Arts  Gold           UK
# 171029  Shooting Men's Military Rifle, Standing, 300 m...  Gold      Denmark
# 173097                           Sailing Mixed 5.5 metres  Gold    Australia
# 190952                         Archery Women's Team Round  Gold          USA
#
#        notes
# 5078     NaN
# 7961     NaN
# 13394    NaN
# 13396    NaN
# 24897    NaN
# 30323    NaN
# 38675    NaN
# 41288    NaN
# 42973    NaN
# 51671    NaN
# 63622    NaN
# 73191    NaN
# 78291    NaN
# 104003   NaN
# 105010   NaN
# 105199   NaN
# 107171   NaN
# 110771   NaN
# 121152   NaN
# 131798   NaN
# 132007   NaN
# 134557   NaN
# 139669   NaN
# 159298   NaN
# 163126   NaN
# 163130   NaN
# 167439   NaN
# 168551   NaN
# 169081   NaN
# 169083   NaN
# 170250   NaN
# 170796   NaN
# 171029   NaN
# 173097   NaN
# 190952   NaN

# %%
masterDisciplines = goldMedals['Sport'][goldMedals['Age'] > 50]
plt.figure(figsize=(20, 10))
plt.tight_layout()
sns.countplot(masterDisciplines)
plt.title('Gold Medals for Athletes Over 50')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
womenInOlympics = merged[(merged.Sex == 'F') &
						(merged.Season == 'Summer')]
print(womenInOlympics.head(10))

sns.set(style="darkgrid")
plt.figure(figsize=(20, 10))
sns.countplot(x='Year', data=womenInOlympics)
plt.title('Women medals per edition of the Games')
plt.show()
# Out:
#      ID                                Name Sex   Age  Height  Weight  \
# 26    8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 27    8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# 32   13                  Minna Maarit Aalto   F  30.0   159.0    55.5
# 33   13                  Minna Maarit Aalto   F  34.0   159.0    55.5
# 79   21           Ragnhild Margrethe Aamodt   F  27.0   163.0     NaN
# 80   22                       Andreea Aanei   F  22.0   170.0   125.0
# 91   29                Willemien Aardenburg   F  22.0     NaN     NaN
# 105  37                  Ann Kristin Aarnes   F  23.0   182.0    64.0
# 135  49                        Moonika Aava   F  24.0   168.0    65.0
# 136  49                        Moonika Aava   F  28.0   168.0    65.0
#
#             Team  NOC        Games    Year  Season            City  \
# 26   Netherlands  NED  1932 Summer  1932.0  Summer     Los Angeles
# 27   Netherlands  NED  1932 Summer  1932.0  Summer     Los Angeles
# 32       Finland  FIN  1996 Summer  1996.0  Summer         Atlanta
# 33       Finland  FIN  2000 Summer  2000.0  Summer          Sydney
# 79        Norway  NOR  2008 Summer  2008.0  Summer         Beijing
# 80       Romania  ROU  2016 Summer  2016.0  Summer  Rio de Janeiro
# 91   Netherlands  NED  1988 Summer  1988.0  Summer           Seoul
# 105       Norway  NOR  1996 Summer  1996.0  Summer         Atlanta
# 135      Estonia  EST  2004 Summer  2004.0  Summer          Athina
# 136      Estonia  EST  2008 Summer  2008.0  Summer         Beijing
#
#              Sport                                    Event   Medal  \
# 26       Athletics             Athletics Women's 100 metres     NaN
# 27       Athletics   Athletics Women's 4 x 100 metres Relay     NaN
# 32         Sailing               Sailing Women's Windsurfer     NaN
# 33         Sailing               Sailing Women's Windsurfer     NaN
# 79        Handball                Handball Women's Handball    Gold
# 80   Weightlifting  Weightlifting Women's Super-Heavyweight     NaN
# 91          Hockey                    Hockey Women's Hockey  Bronze
# 105       Football                Football Women's Football  Bronze
# 135      Athletics          Athletics Women's Javelin Throw     NaN
# 136      Athletics          Athletics Women's Javelin Throw     NaN
#
#           region notes
# 26   Netherlands   NaN
# 27   Netherlands   NaN
# 32       Finland   NaN
# 33       Finland   NaN
# 79        Norway   NaN
# 80       Romania   NaN
# 91   Netherlands   NaN
# 105       Norway   NaN
# 135      Estonia   NaN
# 136      Estonia   NaN

# %%
print(goldMedals.region.value_counts().reset_index(name='Medal').head())

totalGoldMedals = goldMedals.region.value_counts().reset_index(name='Medal').head(5)

g = sns.catplot(x="index", y="Medal", data=totalGoldMedals,
				height=6, kind="bar", palette="muted")
g.despine(left=True)
g.set_xlabels("Top 5 countries")
g.set_ylabels("Number of Medals")
plt.title('Medals per Country')
plt.show()
# Out:
#      index  Medal
# 0      USA   1880
# 1   Russia   1035
# 2  Germany    856
# 3       UK    490
# 4    Italy    431

# %%
MenOverTime = merged[(merged.Sex == 'M') &
					(merged.Season == 'Summer')]
wlMenOverTime = MenOverTime.loc[MenOverTime['Sport'] == 'Weightlifting']

plt.figure(figsize=(20, 10))
sns.pointplot('Year', 'Weight', data=wlMenOverTime, palette='Set2')
plt.title('Weight over year for Male Lifters')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
